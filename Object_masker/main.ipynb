# %%
import tensorflow as tf

# %%
import tensorflow as tf

if tf.test.is_built_with_cuda():
    print("CUDA is available")
else:
    print("CUDA is not available")
# Out:
# CUDA is not available

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import cv2
import numpy as np
import os
from tensorflow.keras.applications import VGG16 
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import matplotlib.pyplot as plt

# %%
Image = cv2.imread(r"F:\backup\Ubuntu\PycharmProjects\NakshaYog\models\meta_detection\valid\1484_png.rf.d8a4d45d33d7053dfb90b425851fb82c.jpg")
plt.imshow(Image)

# %%
resized = cv2.resize(Image, (224,224))
resized.shape
# Out:
# (224, 224, 3)

# %%
model = VGG16(weights='imagenet',input_shape=(224,224,3))
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 42s 0us/step

# %%
processed_image = preprocess_input(resized.reshape(1,224,224,3))
plt.imshow(processed_image[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
predicition = model.predict(processed_image)
print(predicition.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# (1, 1000)

# %%
from tensorflow.keras.applications.vgg16 import decode_predictions

output = decode_predictions(predicition)

# %%
output
# Out:
# [[('n07565083', 'menu', 0.5051217),
#   ('n02840245', 'binder', 0.1501025),
#   ('n06785654', 'crossword_puzzle', 0.034020342),
#   ('n03838899', 'oboe', 0.030980958),
#   ('n03388183', 'fountain_pen', 0.025387669)]]
